# %%
# The code is importing various libraries and modules that will be used in the code.
import pandas as pd
import numpy as np
import nltk
import string
import warnings
import re
warnings.filterwarnings('ignore')

# %%
# The code defines a function called `generate_stopwords()` that reads multiple text files and extracts the stopwords from them.
def generate_stopwords():
    parent_path = "Data/internship_files/StopWords/StopWords_"
    child_paths = ['Auditor', 'Currencies', 'DatesandNumbers','Generic', 'GenericLong', 'Geographic', 'Names']
    words = []
    for child in child_paths:
        text = ""
        with open(f"{parent_path}{child}.txt", 'r', encoding = "utf-8", errors = "ignore") as f:
            words.extend([word for line in f for word in line.split() if word not in ['\n', '|']])
    return words

# %%
# The code is generating a master dictionary by reading text files containing positive and negative words.
def generate_MasterDict(stopwords):
    parent_path = "Data/internship_files/MasterDictionary/"
    child_paths = ['positive-words', 'negative-words']
    words = []
    for child in child_paths:
        text = ""
        with open(f"{parent_path}{child}.txt", 'r', encoding = "utf-8", errors = "ignore") as f:
            words.append([word for line in f for word in line.split() if word not in stopwords+['\n', '|']])
    return words

# %%
def generate_content(url_id)
    text = ""
    with open(f"Data/internship_files/Scrapped_data/url_id-{url_id}.txt", 'r', encoding = "utf-8", errors = "ignore") as f:
        text += f.read()
    sent = nltk.sent_tokenize(text)
    text = text.translate(str.maketrans('','',string.punctuation))
    words = nltk.word_tokenize(text)
    words = [w for w in words if w not in stopwords]
    return sent, words

# %%
# The `AvgSyllable` function is a Python function that calculates various metrics related to syllables and complexity in a given list of words.

def AvgSyllable(words):
    plurals = "aeiouAEIOU"
    total_syallable = 0
    complex_words = 0
    for w in words:
        if not w.endswith(('es', 'ed')):
            syallable = sum([1 for c in w if c in plurals])
            if(syallable > 2): complex_words += 1
            total_syallable += syallable
    syllable_per_word = (total_syallable/len(words))
    complex_percent = (complex_words)/len(words)
    fog_index = 0.4 * (syllable_per_word + complex_percent)
    return syllable_per_word,  complex_words, complex_percent, fog_index

# %%
# The code is defining a regular expression pattern `pronounRegex` that matches common pronouns such as "I", "we", "my", "ours", and "us".
# This function calculating the count of pronouns in the given sentence.
def Calculate_pronouns(sent):
    pronounRegex = re.compile(r'\b(I|we|my|ours|(?-i:us))\b',re.I)
    pronouns = []
    for s in sent:
        if s: pronouns.extend(re.findall(pronounRegex, s))
    pronouns_count = sum([1 for w in pronouns])
    return pronouns_count

# %%
stopwords = generate_stopwords()
MasterWords = generate_MasterDict(stopwords)
Pos_words = MasterWords[0]
Neg_words = MasterWords[1]
df = pd.read_excel("Data/internship_files/Output Data Structure.xlsx")
df.index = df.URL_ID
df.drop(["URL_ID"],axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                                       URL  POSITIVE SCORE  \
# URL_ID
# 37      https://insights.blackcoffer.com/ai-in-healthc...             NaN
# 38      https://insights.blackcoffer.com/what-if-the-c...             NaN
# 39      https://insights.blackcoffer.com/what-jobs-wil...             NaN
# 40      https://insights.blackcoffer.com/will-machine-...             NaN
# 41      https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#         NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# URL_ID
# 37                 NaN             NaN                 NaN
# 38                 NaN             NaN                 NaN
# 39                 NaN             NaN                 NaN
# 40                 NaN             NaN                 NaN
# 41                 NaN             NaN                 NaN
#
#         AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# URL_ID
# 37                      NaN                          NaN        NaN
# 38                      NaN                          NaN        NaN
# 39                      NaN                          NaN        NaN
# 40                      NaN                          NaN        NaN
# 41                      NaN                          NaN        NaN
#
#         AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# URL_ID
# 37                                   NaN                 NaN         NaN
# 38                                   NaN                 NaN         NaN
# 39                                   NaN                 NaN         NaN
# 40                                   NaN                 NaN         NaN
# 41                                   NaN                 NaN         NaN
#
#         SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# URL_ID
# 37                    NaN                NaN              NaN
# 38                    NaN                NaN              NaN
# 39                    NaN                NaN              NaN
# 40                    NaN                NaN              NaN
# 41                    NaN                NaN              NaN

# %%
df.columns
# Out:
# Index(['URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
#        'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],
#       dtype='object')

# %%
# The code snippet is performing several calculations and assignments based on the content generated for a specific URL ID.
for url_id in df.index:
    if url_id not in [44, 57, 144]:
        
        sent, words = generate_content(url_id)
        pos_score = sum([1 for w in words if w in Pos_words])
        neg_score = sum([1 for w in words if w in Neg_words])
        Syllable_per_word , complex_count, complex_percentage, fog_index = AvgSyllable(words)
        pronouns_count = Calculate_pronouns(sent)
        
        
        # The code snippet is assigning values to various columns in a DataFrame `df` based
        # on the calculations and assignments performed in the above code.
        
        df["POSITIVE SCORE"][url_id] =  pos_score
        df["NEGATIVE SCORE"][url_id] = neg_score
        df["POLARITY SCORE"][url_id] = (pos_score - neg_score)/(pos_score + neg_score + 0.000001)
        df['SUBJECTIVITY SCORE'][url_id] = (pos_score + neg_score)/(len(words)+0.000001)
        df['AVG SENTENCE LENGTH'][url_id] = len(words)/len(sent)
        df['PERCENTAGE OF COMPLEX WORDS'][url_id] = complex_percentage
        df['FOG INDEX'][url_id] = fog_index
        df['AVG NUMBER OF WORDS PER SENTENCE'][url_id] = len(words)/len(sent)
        df['COMPLEX WORD COUNT'][url_id] = complex_count
        df["WORD COUNT"][url_id] = len(words)
        df['SYLLABLE PER WORD'][url_id] = Syllable_per_word
        df['PERSONAL PRONOUNS'][url_id] = pronouns_count
        df['AVG WORD LENGTH'][url_id] = sum([len(w) for w in words])/len(words)

# %%
df[:20]
# Out:
#                                                       URL  POSITIVE SCORE  \
# URL_ID
# 37      https://insights.blackcoffer.com/ai-in-healthc...           122.0
# 38      https://insights.blackcoffer.com/what-if-the-c...            56.0
# 39      https://insights.blackcoffer.com/what-jobs-wil...            64.0
# 40      https://insights.blackcoffer.com/will-machine-...            55.0
# 41      https://insights.blackcoffer.com/will-ai-repla...            48.0
# 42      https://insights.blackcoffer.com/man-and-machi...            43.0
# 43      https://insights.blackcoffer.com/in-future-or-...            26.0
# 44      https://insights.blackcoffer.com/how-neural-ne...             NaN
# 45      https://insights.blackcoffer.com/how-machine-l...            36.0
# 46      https://insights.blackcoffer.com/deep-learning...            64.0
# 47      https://insights.blackcoffer.com/how-to-protec...            44.0
# 48      https://insights.blackcoffer.com/how-machines-...            32.0
# 49      https://insights.blackcoffer.com/ai-human-robo...            27.0
# 50      https://insights.blackcoffer.com/how-ai-will-c...            60.0
# 51      https://insights.blackcoffer.com/future-of-wor...           119.0
# 52      https://insights.blackcoffer.com/ai-tool-alexa...            26.0
# 53      https://insights.blackcoffer.com/ai-healthcare...            78.0
# 54      https://insights.blackcoffer.com/all-you-need-...            25.0
# 55      https://insights.blackcoffer.com/evolution-of-...            13.0
# 56      https://insights.blackcoffer.com/how-data-anal...             3.0
#
#         NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# URL_ID
# 37                66.0        0.297872            0.091573
# 38                37.0        0.204301            0.143740
# 39                33.0        0.319588            0.107182
# 40                23.0        0.410256            0.112880
# 41                24.0        0.333333            0.082569
# 42                24.0        0.283582            0.110197
# 43                12.0        0.368421            0.100796
# 44                 NaN             NaN                 NaN
# 45                13.0        0.469388            0.135359
# 46                40.0        0.230769            0.103175
# 47                61.0       -0.161905            0.105954
# 48                19.0        0.254902            0.085000
# 49                24.0        0.058824            0.078462
# 50                24.0        0.428571            0.119318
# 51                44.0        0.460123            0.105502
# 52                 0.0        1.000000            0.092527
# 53                39.0        0.333333            0.162500
# 54                 0.0        1.000000            0.050000
# 55                 6.0        0.368421            0.047619
# 56                 4.0       -0.142857            0.043750
#
#         AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# URL_ID
# 37                13.871622                     0.476376   1.153434
# 38                 8.087500                     0.353941   0.961360
# 39                10.647059                     0.456354   1.115138
# 40                 7.677778                     0.383502   1.049493
# 41                10.380952                     0.387615   1.037156
# 42                10.482759                     0.384868   1.040132
# 43                 8.195652                     0.318302   0.926260
# 44                      NaN                          NaN        NaN
# 45                 9.783784                     0.370166   0.960221
# 46                12.292683                     0.414683   1.090873
# 47                10.431579                     0.394551   1.038547
# 48                10.714286                     0.475000   1.166000
# 49                 7.926829                     0.375385   1.017846
# 50                10.507463                     0.403409   1.062500
# 51                 9.656250                     0.402589   1.059676
# 52                12.772727                     0.498221   1.201423
# 53                80.000000                     0.430556   1.091667
# 54                 9.090909                     0.460000   1.094400
# 55                 9.975000                     0.446115   1.097744
# 56                12.307692                     0.381250   1.010000
#
#         AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# URL_ID
# 37                             13.871622               978.0      2053.0
# 38                              8.087500               229.0       647.0
# 39                             10.647059               413.0       905.0
# 40                              7.677778               265.0       691.0
# 41                             10.380952               338.0       872.0
# 42                             10.482759               234.0       608.0
# 43                              8.195652               120.0       377.0
# 44                                   NaN                 NaN         NaN
# 45                              9.783784               134.0       362.0
# 46                             12.292683               418.0      1008.0
# 47                             10.431579               391.0       991.0
# 48                             10.714286               285.0       600.0
# 49                              7.926829               244.0       650.0
# 50                             10.507463               284.0       704.0
# 51                              9.656250               622.0      1545.0
# 52                             12.772727               140.0       281.0
# 53                             80.000000               310.0       720.0
# 54                              9.090909               230.0       500.0
# 55                              9.975000               178.0       399.0
# 56                             12.307692                61.0       160.0
#
#         SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# URL_ID
# 37               2.407209                2.0         7.442280
# 38               2.049459                7.0         6.746522
# 39               2.331492                2.0         7.335912
# 40               2.240232               16.0         6.674385
# 41               2.205275               14.0         6.876147
# 42               2.215461               18.0         6.886513
# 43               1.997347                7.0         6.795756
# 44                    NaN                NaN              NaN
# 45               2.030387                0.0         6.392265
# 46               2.312500                9.0         6.895833
# 47               2.201816                1.0         6.766902
# 48               2.440000               10.0         7.303333
# 49               2.169231                6.0         6.636923
# 50               2.252841               32.0         7.110795
# 51               2.246602               18.0         7.027832
# 52               2.505338                0.0         7.501779
# 53               2.298611               14.0         6.948611
# 54               2.276000                0.0         6.820000
# 55               2.298246                0.0         7.438596
# 56               2.143750                2.0         7.125000

# %%
# It is saving the DataFrame `df` to an Excel file named "Blackcoffer_OUTPUT.xlsx".
df.to_excel("Blackcoffer_OUTPUT.xlsx")
